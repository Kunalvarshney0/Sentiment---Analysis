# %% [markdown]
# Importing the packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import nltk
import wordcloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from nltk.corpus import stopwords

# %% [markdown]
# Importing Dataset

# %%
df = pd.read_csv("/content/Amazondata.csv")

# %%
print(df)
# Out:
#                         id             dateAdded           dateUpdated  \
# 0     AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1     AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2     AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3     AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4     AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# ...                    ...                   ...                   ...
# 4995  AVqkIdZiv8e3D1O-leaJ  2017-03-06T14:59:25Z  2017-09-04T11:19:31Z
# 4996  AVqkIdZiv8e3D1O-leaJ  2017-03-06T14:59:25Z  2017-09-04T11:19:31Z
# 4997  AVqkIdZiv8e3D1O-leaJ  2017-03-06T14:59:25Z  2017-09-04T11:19:31Z
# 4998  AVqkIdZiv8e3D1O-leaJ  2017-03-06T14:59:25Z  2017-09-04T11:19:31Z
# 4999  AVqkIdZiv8e3D1O-leaJ  2017-03-06T14:59:25Z  2017-09-04T11:19:31Z
#
#                                                    name       asins   brand  \
# ...

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# ...

# %%
 df.shape
# Out:
# (5000, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   5000 non-null   object
#  1   dateAdded            5000 non-null   object
#  2   dateUpdated          5000 non-null   object
#  3   name                 5000 non-null   object
#  4   asins                5000 non-null   object
#  5   brand                5000 non-null   object
#  6   categories           5000 non-null   object
#  7   primaryCategories    5000 non-null   object
#  8   imageURLs            5000 non-null   object
#  9   keys                 5000 non-null   object
#  10  manufacturer         5000 non-null   object
#  11  manufacturerNumber   5000 non-null   object
#  12  reviews.date         5000 non-null   object
#  13  reviews.dateAdded    1052 non-null   object
#  14  reviews.dateSeen     5000 non-null   object
# ...

# %% [markdown]
# Since all variables are not important for analysis so we will use only necessary variables and remove others.

# %%
data = df[["name","reviews.text","reviews.rating"]]

# %%
data.head()
# Out:
#                                                 name  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...
#
#                                         reviews.text  reviews.rating
# 0  I thought it would be as big as small paper bu...               3
# 1  This kindle is light and easy to use especiall...               5
# 2  Didnt know how much i'd use a kindle so went f...               4
# 3  I am 100 happy with my purchase. I caught it o...               5
# 4  Solid entry level Kindle. Great for kids. Gift...               5

# %% [markdown]
# Droping missing values

# %%
data.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
data.isnull().sum()
# Out:
# name              0
# reviews.text      0
# reviews.rating    0
# dtype: int64

# %% [markdown]
# Descriptive Statistics

# %%
data.describe()
# Out:
#        reviews.rating
# count     5000.000000
# mean         4.596800
# std          0.731804
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000

# %% [markdown]
# Distribution of reviews ratings

# %%
data['reviews.rating'].value_counts().sort_index()
# Out:
# 1      63
# 2      54
# 3     197
# 4    1208
# 5    3478
# Name: reviews.rating, dtype: int64

# %%
sns.countplot(data['reviews.rating'], palette='Reds')
plt.title('Distribution of Review Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
ratings = data["reviews.rating"].value_counts()

# %%
quantity = ratings.values

# %%
names = ratings.index

# %%
import plotly.express as px

# %%
figure = px.pie(data, 
             values = quantity, 
             names = names, 
             hole = 0.5,
                title='Percentage wise distribution of the reviews')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Mapping ratings 1, 2 to 0 (Negative) ,
#                 3 to 1 (Neutral) ,
#                 4, 5 to 2 (Positive)

# %%
sentiment_score = {1:0,
                  2:0,
                  3:1,
                  4:2,
                  5:2}

# %%
sentiment = {0 : 'NEGATIVE',
            1 : 'NEUTRAL',
            2 : 'POSITIVE'}

# %%
data['sentiment_score'] = data['reviews.rating'].map(sentiment_score)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data['sentiment'] = data['sentiment_score'].map(sentiment)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data.head(10)
# Out:
#                                                 name  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 5  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 6  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 7  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 8  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 9  Amazon Kindle E-Reader 6" Wifi (8th Generation...
#
#                                         reviews.text  reviews.rating  \
# 0  I thought it would be as big as small paper bu...               3
# 1  This kindle is light and easy to use especiall...               5
# 2  Didnt know how much i'd use a kindle so went f...               4
# 3  I am 100 happy with my purchase. I caught it o...               5
# ...

# %%
data['sentiment_score'].value_counts()
# Out:
# 2    4686
# 1     197
# 0     117
# Name: sentiment_score, dtype: int64

# %%
data['sentiment'].value_counts()
# Out:
# POSITIVE    4686
# NEUTRAL      197
# NEGATIVE     117
# Name: sentiment, dtype: int64

# %% [markdown]
# Distribution of sentiments

# %%
fig = px.pie(data,
            values = data['sentiment'].value_counts(),
             names = data['sentiment'].value_counts().index,
            hole = 0,
            title = 'Distribution Of Sentiment')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Getting all words used in the reviews

# %%
all_words = pd.Series(' '.join(data['reviews.text']).split())

# %%
all_words.head(25)
# Out:
# 0           I
# 1     thought
# 2          it
# 3       would
# 4          be
# 5          as
# 6         big
# 7          as
# 8       small
# 9       paper
# 10        but
# 11       turn
# 12        out
# 13         to
# 14         be
# 15       just
# 16       like
# 17         my
# 18      palm.
# 19          I
# 20      think
# 21         it
# 22         is
# 23        too
# 24      small
# dtype: object

# %% [markdown]
# Word Cloud before cleaning data.

# %%
wordcloud = WordCloud(width = 1000, height = 600).generate(' '.join(all_words))
plt.figure(figsize=(20,18))
plt.title("Most used words in the reviews", size = 20)
plt.axis('off')
plt.imshow(wordcloud)

# %%
nltk.download('stopwords')
stemmer = nltk.SnowballStemmer("english")
stopword=set(stopwords.words('english'))
import string
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# Cleaning Data

# %%
def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text

# %%
data['reviews.text'] = data['reviews.text'].apply(clean)

# %% [markdown]
# Word Cloud after cleaning data.

# %%
text = " ".join(i for i in data['reviews.text'])
stopwords = set(STOPWORDS)
wc = WordCloud(stopwords = stopwords, width = 1000, height = 600).generate(text)
plt.figure(figsize=(20,18))
plt.imshow(wc)
plt.axis('off')
plt.show()

# %% [markdown]
# # **Conclusion:**
# So, from the above analysis it can be derived that majority of the customers are satisfied with the products as around 94 % people have given postive feedback in the reviews and only a small portion of customers is unsatisfied with the company which can also be seen through wordcloud. Major words in the reviews are GREAT, LOVE, USE, GOOD, etc which shows a positive sentiment of customers.
